# %%
import tensorflow as tf
import numpy as np
import tensorflow.keras.layers as Layers
import cv2
import matplotlib.pyplot as plt

# %%
model= tf.keras.models.load_model('my_model.h5')

# %%
image = cv2.imread('tulip.jpg')

# %%
image = cv2.resize(image,(120,120))

# %%
image = image/255

# %%
image.max()
# Out:
# 1.0

# %%
image.min()
# Out:
# 0.0

# %%
image.shape
# Out:
# (120, 120, 3)

# %%
image = np.array(image)

plt.imshow(image)
img_real = image
image = np.reshape(image,(1,120,120,3))

# %%
#['tulip', 'daisy', 'sunflower', 'rose', 'dandelion']
#model.predict_classes(tf.cast(pred_image, tf.float32))
pred_list = model.predict(image)[0]
print(np.argmax(pred_list))
# Out:
# 0
